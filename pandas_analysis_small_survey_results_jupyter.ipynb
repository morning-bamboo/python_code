# %%
import pandas as pd
import numpy as np

# %%
survey_df = pd.read_csv("small_survey_results.csv")
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0         20900  I am a developer by profession      Yes   NaN         10
# 1         28235  I am a developer by profession       No  45.0         10
# 2         26082  I am a developer by profession      Yes  23.0         14
# 3         19890  I am a developer by profession      Yes  61.0         21
# 4         16393  I am a developer by profession      Yes  25.0         15
# ..          ...                             ...      ...   ...        ...
# 995       51360  I am a developer by profession      Yes  26.0         13
# 996       16771  I am a developer by profession      Yes   NaN         11
# 997       38831  I am a developer by profession      Yes   NaN        NaN
# 998        7093  I am a developer by profession      Yes   NaN        NaN
# 999       51843  I am a developer by profession      Yes  29.0         20
#
#     CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# ...

# %%
survey_df.set_index("Respondent",inplace=True)

# %%
# survey_df.sort_values(by="Age",ascending = False)

survey_df.sort_values(by=["Age","YearsCode"],ascending = [False,True])[["Age","YearsCode"]] #sort multiple col

survey_df["Age"].sort_values() #sort in age col 

survey_df["ConvertedComp"].nlargest(5)
# Out:
# Respondent
# 29378    1000000.0
# 48807    1000000.0
# 18603     946944.0
# 5292      907572.0
# 28235     867480.0
# Name: ConvertedComp, dtype: float64

# %%
richest_group = survey_df.nlargest(10, "ConvertedComp")[["ConvertedComp","DevType","EdLevel"]]
richest_group
# Out:
#             ConvertedComp                                            DevType  \
# Respondent
# 29378           1000000.0  Data or business analyst;Data scientist or mac...
# 48807           1000000.0                                                NaN
# 18603            946944.0         Database administrator;Developer, back-end
# 5292             907572.0                                Developer, back-end
# 28235            867480.0                                  Developer, mobile
# 19800            863316.0           Developer, back-end;Developer, front-end
# 47454            843168.0  Developer, back-end;Developer, full-stack;Deve...
# 21172            801720.0  Developer, back-end;Developer, front-end;Devel...
# 59314            753936.0  Data scientist or machine learning specialist;...
# 26443            744000.0  Developer, back-end;Developer, desktop or ente...
#
#                                                       EdLevel
# Respondent
# ...

# %%
for col_name, col_data in survey_df.items():  #iterating in col
    print(col_name)
    print(col_data)

    break
# Out:
# MainBranch
# Respondent
# 20900    I am a developer by profession
# 28235    I am a developer by profession
# 26082    I am a developer by profession
# 19890    I am a developer by profession
# 16393    I am a developer by profession
#                       ...
# 51360    I am a developer by profession
# 16771    I am a developer by profession
# 38831    I am a developer by profession
# 7093     I am a developer by profession
# 51843    I am a developer by profession
# Name: MainBranch, Length: 1000, dtype: object

# %%
for row_name, row_data in survey_df.iterrows(): #iterating in row
    print(row_name)
    print(row_data)

    break
# Out:
# 20900
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     10
# CompFreq                                                                  Monthly
# CompTotal                                                                  8000.0
# ConvertedComp                                                             53040.0
# Country                                                                  Bulgaria
# CurrencyDesc                                                        Bulgarian lev
# CurrencySymbol                                                                BGN
# DatabaseDesireNextYear                                            Cassandra;Redis
# ...

# %%
inversed_df = pd.DataFrame({row_name:row_data for row_name, row_data in survey_df.iterrows()})
inversed_df
# Out:
#                                                                           20900  \
# MainBranch                                       I am a developer by profession
# Hobbyist                                                                    Yes
# Age                                                                         NaN
# Age1stCode                                                                   10
# CompFreq                                                                Monthly
# CompTotal                                                                8000.0
# ConvertedComp                                                           53040.0
# Country                                                                Bulgaria
# CurrencyDesc                                                      Bulgarian lev
# CurrencySymbol                                                              BGN
# DatabaseDesireNextYear                                          Cassandra;Redis
# ...

# %%
survey_df
# Out:
#      respondent                      mainbranch hobbyist  user age age1stcode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      23.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df.columns
survey_df.rename(columns = {"Age":"user age","OrgSize":"Organization Size"},inplace=True)
survey_df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'user age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'Organization Size', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
survey_df.reset_index(inplace=True)
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist  user age Age1stCode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      23.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df.columns = survey_df.columns.str.lower()
survey_df
# Out:
#      respondent                      mainbranch hobbyist  user age age1stcode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      23.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df["jobfactors"]
# Out:
# 0      Industry that I’d be working in;Flex time or a...
# 1      Industry that I’d be working in;Flex time or a...
# 2      Industry that I’d be working in;Languages, fra...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I’d be working in;Flex time or a...
#                              ...
# 995    Flex time or a flexible schedule;Languages, fr...
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999    Languages, frameworks, and other technologies ...
# Name: jobfactors, Length: 1000, dtype: object

# %%
survey_df["jobfactors"] = survey_df["jobfactors"].str.lower()

# %%
survey_df["jobfactors"]
# Out:
# 0      industry that i’d be working in;flex time or a...
# 1      industry that i’d be working in;flex time or a...
# 2      industry that i’d be working in;languages, fra...
# 3      languages, frameworks, and other technologies ...
# 4      industry that i’d be working in;flex time or a...
#                              ...
# 995    flex time or a flexible schedule;languages, fr...
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999    languages, frameworks, and other technologies ...
# Name: jobfactors, Length: 1000, dtype: object

# %%
survey_df.loc[2,"trans"]= "Yes"
survey_df.loc[2,["user_age","country"]]=[24,"China"]
survey_df.loc[2,["trans","user_age","country"]]
# Out:
# trans         Yes
# user_age     24.0
# country     China
# Name: 2, dtype: object

# %%
survey_df.loc[~(survey_df["user_age"]<18),["age_group"]] = "adult"

# %%
survey_df
# Out:
#      respondent                      mainbranch hobbyist  user age age1stcode  \
# 0         20900  I am a developer by profession      Yes       NaN         10
# 1         28235  I am a developer by profession       No      45.0         10
# 2         26082  I am a developer by profession      Yes      23.0         14
# 3         19890  I am a developer by profession      Yes      61.0         21
# 4         16393  I am a developer by profession      Yes      25.0         15
# ..          ...                             ...      ...       ...        ...
# 995       51360  I am a developer by profession      Yes      26.0         13
# 996       16771  I am a developer by profession      Yes       NaN         11
# 997       38831  I am a developer by profession      Yes       NaN        NaN
# 998        7093  I am a developer by profession      Yes       NaN        NaN
# 999       51843  I am a developer by profession      Yes      29.0         20
#
# ...

# %%
survey_df["gen_col"] = survey_df["gender"]+survey_df["trans"]

# %%
new_survey = {"user_age":25,"country":"China","age1stcode":"24"}
new_survey_df= pd.DataFrame(new_survey, index=[0])
new_survey_df
# Out:
#    user_age country age1stcode
# 0        25   China         24

# %%
survey_df = pd.concat([survey_df,new_survey_df],ignore_index=True)

survey_df
# Out:
#       respondent                      mainbranch hobbyist  user age  \
# 0        20900.0  I am a developer by profession      Yes       NaN
# 1        28235.0  I am a developer by profession       No      45.0
# 2        26082.0  I am a developer by profession      Yes      23.0
# 3        19890.0  I am a developer by profession      Yes      61.0
# 4        16393.0  I am a developer by profession      Yes      25.0
# ...          ...                             ...      ...       ...
# 997      38831.0  I am a developer by profession      Yes       NaN
# 998       7093.0  I am a developer by profession      Yes       NaN
# 999      51843.0  I am a developer by profession      Yes      29.0
# 1000         NaN                             NaN      NaN       NaN
# 1001         NaN                             NaN      NaN       NaN
#
#      age1stcode compfreq  comptotal  convertedcomp      country  \
# 0            10  Monthly     8000.0        53040.0     Bulgaria
# ...

# %%
survey_df.drop(columns=["age_group"],inplace=True)

survey_df
# Out:
#       respondent                      mainbranch hobbyist  user age  \
# 0        20900.0  I am a developer by profession      Yes       NaN
# 1        28235.0  I am a developer by profession       No      45.0
# 2        26082.0  I am a developer by profession      Yes      23.0
# 3        19890.0  I am a developer by profession      Yes      61.0
# 4        16393.0  I am a developer by profession      Yes      25.0
# ...          ...                             ...      ...       ...
# 997      38831.0  I am a developer by profession      Yes       NaN
# 998       7093.0  I am a developer by profession      Yes       NaN
# 999      51843.0  I am a developer by profession      Yes      29.0
# 1000         NaN                             NaN      NaN       NaN
# 1001         NaN                             NaN      NaN       NaN
#
#      age1stcode compfreq  comptotal  convertedcomp      country  \
# 0            10  Monthly     8000.0        53040.0     Bulgaria
# ...

# %%
survey_df.drop(index=1000)
# Out:
#       respondent                      mainbranch hobbyist  user age  \
# 0        20900.0  I am a developer by profession      Yes       NaN
# 1        28235.0  I am a developer by profession       No      45.0
# 2        26082.0  I am a developer by profession      Yes      23.0
# 3        19890.0  I am a developer by profession      Yes      61.0
# 4        16393.0  I am a developer by profession      Yes      25.0
# ...          ...                             ...      ...       ...
# 996      16771.0  I am a developer by profession      Yes       NaN
# 997      38831.0  I am a developer by profession      Yes       NaN
# 998       7093.0  I am a developer by profession      Yes       NaN
# 999      51843.0  I am a developer by profession      Yes      29.0
# 1001         NaN                             NaN      NaN       NaN
#
#      age1stcode compfreq  comptotal  convertedcomp        country  \
# 0            10  Monthly     8000.0        53040.0       Bulgaria
# ...

# %%
age_filter = survey_df["user age"] < 50
index = survey_df[age_filter].index
survey_df.drop(index)
# Out:
#       respondent                                         mainbranch hobbyist  \
# 0        20900.0                     I am a developer by profession      Yes
# 3        19890.0                     I am a developer by profession      Yes
# 11       63975.0                     I am a developer by profession       No
# 15       42246.0                     I am a developer by profession       No
# 22       52375.0  I am not primarily a developer, but I write co...      Yes
# ...          ...                                                ...      ...
# 996      16771.0                     I am a developer by profession      Yes
# 997      38831.0                     I am a developer by profession      Yes
# 998       7093.0                     I am a developer by profession      Yes
# 1000         NaN                                                NaN      NaN
# 1001         NaN                                                NaN      NaN
#
# ...

# %%
# newuser = survey_df[survey_df["hobbyist"]=="Yes"][survey_df["user age"]<25]

# survey_df.loc["code_year"] = survey_df["user_age"] - survey_df["age1stcode"]




filter1 = (survey_df["hobbyist"]=="Yes") & (survey_df["user age"]<25)
filter1_data = survey_df.loc[filter1]

survey_df.loc[filter1, "code_year"] = filter1_data["user_age"] - filter1_data["age1stcode"].astype(int)
survey_df["code_year"]
# Out:
# 0        NaN
# 1        NaN
# 2       10.0
# 3        NaN
# 4        NaN
#         ...
# 997      NaN
# 998      NaN
# 999      NaN
# 1000     NaN
# 1001     NaN
# Name: code_year, Length: 1002, dtype: float64

# %%
dtypes = survey_df.dtypes
str_cols = [col_name for col_name in dtypes.index if dtypes[col_name] == "object"]
survey_df[str_cols]=survey_df[str_cols]

# %%
# survey_df["hobbyist"].apply(len)
survey_df["hobbyist"].apply(lambda x:x.upper())
# Out:
# 0       YES
# 1        NO
# 2       YES
# 3       YES
# 4       YES
#        ...
# 997     YES
# 998     YES
# 999     YES
# 1000    NAN
# 1001    NAN
# Name: hobbyist, Length: 1002, dtype: object

# %%
survey_df.apply(len,axis="columns")
# Out:
# 0       62
# 1       62
# 2       62
# 3       62
# 4       62
#         ..
# 997     62
# 998     62
# 999     62
# 1000    62
# 1001    62
# Length: 1002, dtype: int64

# %%
survey_df["hobbyist"]
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 997     Yes
# 998     Yes
# 999     Yes
# 1000    nan
# 1001    nan
# Name: hobbyist, Length: 1002, dtype: object

# %%
map_dict = {"Yes":"True"}
survey_df["hobbyist"].map(map_dict)

# survey_df["hobbyist"].replace(map_dict)
# Out:
# 0       True
# 1        NaN
# 2       True
# 3       True
# 4       True
#         ...
# 997     True
# 998     True
# 999     True
# 1000     NaN
# 1001     NaN
# Name: hobbyist, Length: 1002, dtype: object

# %%
survey_df
# Out:
#       respondent                      mainbranch hobbyist  user age  \
# 0        20900.0  I am a developer by profession      Yes       NaN
# 1        28235.0  I am a developer by profession       No      45.0
# 2        26082.0  I am a developer by profession      Yes      23.0
# 3        19890.0  I am a developer by profession      Yes      61.0
# 4        16393.0  I am a developer by profession      Yes      25.0
# ...          ...                             ...      ...       ...
# 997      38831.0  I am a developer by profession      Yes       NaN
# 998       7093.0  I am a developer by profession      Yes       NaN
# 999      51843.0  I am a developer by profession      Yes      29.0
# 1000         NaN                             nan      nan       NaN
# 1001         NaN                             nan      nan       NaN
#
#      age1stcode compfreq  comptotal  convertedcomp      country  \
# 0            10  Monthly     8000.0        53040.0     Bulgaria
# ...

# %%
survey_df["hobbyist"].apply(len)
# Out:
# 0       3
# 1       2
# 2       3
# 3       3
# 4       3
#        ..
# 997     3
# 998     3
# 999     3
# 1000    3
# 1001    3
# Name: hobbyist, Length: 1002, dtype: int64
